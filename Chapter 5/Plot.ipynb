# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
# %matplotlib inline

# %%
test = tf.keras.preprocessing.image.load_img('test.png')

# %%
type(test)
# Out:
# PIL.Image.Image

# %%
from PIL import Image

# %%
test2 = Image.open('test.png')

# %%
NotImplementedError

# %%
np.array(test2).shape
# Out:
# (480, 640, 4)

# %%
np.array(test2)[..., 0].shape
# Out:
# (480, 640)

# %%
plt.imshow(np.array(test2)[..., 3].astype('uint8'))

# %%
plt.plot([1,2], [3,2])

# %%
plt.hist(np.load('test.npy'))
# Out:
# array([ 0, 11, 59, ..., 16, 50, 47])
