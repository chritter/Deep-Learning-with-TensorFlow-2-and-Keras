# %%
test='/root/Deep-Learning-with-TensorFlow-2-and-Keras/test.png'

# %%
import PIL

# %%
PIL.Image.open(test)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2], [3,2])

# %%
plt.savefig('test2.png')

# %%
from IPython.display import Image

# %%
img = PIL.Image.open('/root/Deep-Learning-with-TensorFlow-2-and-Keras/test2.png', mode='r')
img.show()

# %%
display(Image('/root/Deep-Learning-with-TensorFlow-2-and-Keras/test2.png'))

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('/root/Deep-Learning-with-TensorFlow-2-and-Keras/test.png', 'r')
imshow(np.asarray(pil_im))

# %%
np.unique(np.asarray(pil_im))
# Out:
# array([255], dtype=uint8)
